# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib
from scipy.stats import linregress
from citipy import citipy

# %%
# Import API key
weather_api_key = "a538196c2c84f4c1a8d33c1486d1f4b4"

# %%
# Incorporated citipy to determine city based on latitude and longitude

# Output File (CSV)
output_data_file = "cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lings = []
cities = []

# Create a set of random lat and lng combinations
#ateleast 1500 cities
lats = np.random.uniform(low=-90.000, high=90.000, size = 1500)

lngs = np.random.uniform(low=-190.000, high=190.000, size = 1500)
lat_lings = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
#loop through lat_lings, find nearest city and store in city_name
for lat_lng in lat_lings:
    city=citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
     # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %% [markdown]
# # Perform API calls

# %%
weather_api_key = "a538196c2c84f4c1a8d33c1486d1f4b4"
 # Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# List of city data (to store all the city data from API calls)
city_data = []

# %%
# Print to logger
print("Beginning Data Retrieval")
print("-----------------------------")

# Create counters(that help us to track how many calls we done)
record_count = 1
set_count = 1

# Loop through all the cities in our list
#work i as counter as cities as values, 
#use enumerate allow us to loop over something that havent automatic counter
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | souillac
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | ahipara
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | antigonish
# Processing Record 7 of Set 1 | clyde river
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | ocosingo
# Processing Record 10 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 1 | karratha
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | meulaboh
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | yar-sale
# Processing Record 16 of Set 1 | thompson
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | vila velha
# Processing Record 19 of Set 1 | victoria
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | upernavik
# Processing Record 22 of Set 1 | magistralnyy
# Processing Record 23 of Set 1 | ilo
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | las vegas
# Processing Record 26 of Set 1 | longyearbyen
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | shebunino
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | moron
# Processing Record 31 of Set 1 | labuhan
# Processing Record 32 of Set 1 | penzance
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | lavrentiya
# Processing Record 38 of Set 1 | verkhnyaya khava
# Processing Record 39 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 1 | alofi
# Processing Record 41 of Set 1 | ituni
# City not found. Skipping...
# Processing Record 42 of Set 1 | mehamn
# Processing Record 43 of Set 1 | olafsvik
# Processing Record 44 of Set 1 | cockburn town
# Processing Record 45 of Set 1 | belyy yar
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | jerome
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | necochea
# Processing Record 0 of Set 2 | korla
# Processing Record 1 of Set 2 | guanica
# Processing Record 2 of Set 2 | nantucket
# Processing Record 3 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 2 | iqaluit
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | latung
# Processing Record 7 of Set 2 | asau
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 2 | san policarpo
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | namatanai
# Processing Record 14 of Set 2 | roald
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | saint-philippe
# Processing Record 17 of Set 2 | xining
# Processing Record 18 of Set 2 | flinders
# Processing Record 19 of Set 2 | khatanga
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | ketchikan
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 2 | san jose
# Processing Record 25 of Set 2 | prado
# Processing Record 26 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | egvekinot
# Processing Record 29 of Set 2 | saint george
# Processing Record 30 of Set 2 | klaksvik
# Processing Record 31 of Set 2 | cayenne
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | mabaruma
# Processing Record 35 of Set 2 | esperance
# Processing Record 36 of Set 2 | logan
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | madras
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | assiniboia
# Processing Record 41 of Set 2 | jieshi
# Processing Record 42 of Set 2 | hit
# Processing Record 43 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 2 | muros
# Processing Record 45 of Set 2 | hermanus
# Processing Record 46 of Set 2 | nouadhibou
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 0 of Set 3 | daru
# Processing Record 1 of Set 3 | srednekolymsk
# Processing Record 2 of Set 3 | pevek
# Processing Record 3 of Set 3 | kahului
# Processing Record 4 of Set 3 | dunedin
# Processing Record 5 of Set 3 | leningradskiy
# Processing Record 6 of Set 3 | kaitangata
# Processing Record 7 of Set 3 | bandarbeyla
# Processing Record 8 of Set 3 | diveyevo
# Processing Record 9 of Set 3 | san quintin
# Processing Record 10 of Set 3 | hueyapan
# Processing Record 11 of Set 3 | udachnyy
# Processing Record 12 of Set 3 | chuy
# Processing Record 13 of Set 3 | oistins
# Processing Record 14 of Set 3 | poum
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 17 of Set 3 | fortuna
# Processing Record 18 of Set 3 | karasjok
# Processing Record 19 of Set 3 | qaanaaq
# Processing Record 20 of Set 3 | mayumba
# Processing Record 21 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 3 | albany
# Processing Record 23 of Set 3 | devils lake
# Processing Record 24 of Set 3 | fairbanks
# Processing Record 25 of Set 3 | kuito
# Processing Record 26 of Set 3 | cherskiy
# Processing Record 27 of Set 3 | nogliki
# Processing Record 28 of Set 3 | padang
# Processing Record 29 of Set 3 | hobart
# Processing Record 30 of Set 3 | jupiter
# Processing Record 31 of Set 3 | bonthe
# Processing Record 32 of Set 3 | bandundu
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | talnakh
# Processing Record 35 of Set 3 | biak
# Processing Record 36 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 3 | yangjiang
# Processing Record 38 of Set 3 | impfondo
# Processing Record 39 of Set 3 | inta
# Processing Record 40 of Set 3 | torbay
# Processing Record 41 of Set 3 | coquimbo
# Processing Record 42 of Set 3 | tamandare
# Processing Record 43 of Set 3 | natal
# Processing Record 44 of Set 3 | lebu
# Processing Record 45 of Set 3 | tasiilaq
# Processing Record 46 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 47 of Set 3 | krasnoye
# Processing Record 48 of Set 3 | berlevag
# Processing Record 49 of Set 3 | saskylakh
# Processing Record 0 of Set 4 | hithadhoo
# Processing Record 1 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 2 of Set 4 | van wert
# Processing Record 3 of Set 4 | pisco
# Processing Record 4 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 4 | kecel
# Processing Record 6 of Set 4 | yaan
# Processing Record 7 of Set 4 | hilo
# Processing Record 8 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 4 | sumbe
# Processing Record 10 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 4 | tanout
# Processing Record 12 of Set 4 | bengkulu
# Processing Record 13 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 4 | guerrero negro
# Processing Record 15 of Set 4 | carnarvon
# Processing Record 16 of Set 4 | namwala
# Processing Record 17 of Set 4 | samara
# Processing Record 18 of Set 4 | lakitelek
# Processing Record 19 of Set 4 | cannes
# Processing Record 20 of Set 4 | mackenzie
# Processing Record 21 of Set 4 | mareeba
# Processing Record 22 of Set 4 | keti bandar
# Processing Record 23 of Set 4 | kawalu
# Processing Record 24 of Set 4 | groa
# Processing Record 25 of Set 4 | lockhart
# Processing Record 26 of Set 4 | potosi
# Processing Record 27 of Set 4 | mani
# Processing Record 28 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 4 | rock sound
# Processing Record 30 of Set 4 | nanortalik
# Processing Record 31 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 32 of Set 4 | arraial do cabo
# Processing Record 33 of Set 4 | san cristobal
# Processing Record 34 of Set 4 | kruisfontein
# Processing Record 35 of Set 4 | visnes
# Processing Record 36 of Set 4 | riyadh
# Processing Record 37 of Set 4 | copiapo
# Processing Record 38 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 4 | ribeira grande
# Processing Record 40 of Set 4 | huainan
# Processing Record 41 of Set 4 | naryan-mar
# Processing Record 42 of Set 4 | tuatapere
# Processing Record 43 of Set 4 | lookan
# Processing Record 44 of Set 4 | port blair
# Processing Record 45 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 4 | tommot
# Processing Record 47 of Set 4 | marawi
# Processing Record 48 of Set 4 | vardo
# Processing Record 49 of Set 4 | provideniya
# Processing Record 0 of Set 5 | tawnat
# City not found. Skipping...
# Processing Record 1 of Set 5 | nsanje
# Processing Record 2 of Set 5 | zhanaozen
# Processing Record 3 of Set 5 | general roca
# Processing Record 4 of Set 5 | antalaha
# Processing Record 5 of Set 5 | zelenoborskiy
# Processing Record 6 of Set 5 | kayerkan
# Processing Record 7 of Set 5 | komsomolskiy
# Processing Record 8 of Set 5 | la paz
# Processing Record 9 of Set 5 | robertsport
# Processing Record 10 of Set 5 | salihli
# Processing Record 11 of Set 5 | avera
# Processing Record 12 of Set 5 | tigil
# Processing Record 13 of Set 5 | batagay
# Processing Record 14 of Set 5 | jumla
# Processing Record 15 of Set 5 | port lincoln
# Processing Record 16 of Set 5 | tiznit
# Processing Record 17 of Set 5 | mnogovershinnyy
# Processing Record 18 of Set 5 | camopi
# Processing Record 19 of Set 5 | praia
# Processing Record 20 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 5 | ugoofaaru
# Processing Record 22 of Set 5 | anchorage
# Processing Record 23 of Set 5 | sao sebastiao
# Processing Record 24 of Set 5 | baft
# Processing Record 25 of Set 5 | dalvik
# Processing Record 26 of Set 5 | grand-santi
# Processing Record 27 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 28 of Set 5 | bambous virieux
# Processing Record 29 of Set 5 | griffith
# Processing Record 30 of Set 5 | panama city
# Processing Record 31 of Set 5 | darhan
# Processing Record 32 of Set 5 | tiksi
# Processing Record 33 of Set 5 | batemans bay
# Processing Record 34 of Set 5 | cabo san lucas
# Processing Record 35 of Set 5 | noumea
# Processing Record 36 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | melfi
# Processing Record 38 of Set 5 | ewo
# Processing Record 39 of Set 5 | yumen
# Processing Record 40 of Set 5 | elias fausto
# Processing Record 41 of Set 5 | cap malheureux
# Processing Record 42 of Set 5 | uinskoye
# Processing Record 43 of Set 5 | akdepe
# Processing Record 44 of Set 5 | saint-augustin
# Processing Record 45 of Set 5 | chalchihuites
# Processing Record 46 of Set 5 | norman wells
# Processing Record 47 of Set 5 | zyryanka
# Processing Record 48 of Set 5 | henties bay
# Processing Record 49 of Set 5 | bethel
# Processing Record 0 of Set 6 | mayo
# Processing Record 1 of Set 6 | mehriz
# Processing Record 2 of Set 6 | gosainganj
# Processing Record 3 of Set 6 | vestmannaeyjar
# Processing Record 4 of Set 6 | liuzhou
# Processing Record 5 of Set 6 | ostrovnoy
# Processing Record 6 of Set 6 | kaeo
# Processing Record 7 of Set 6 | porto novo
# Processing Record 8 of Set 6 | los llanos de aridane
# Processing Record 9 of Set 6 | ridgecrest
# Processing Record 10 of Set 6 | ruidoso
# Processing Record 11 of Set 6 | moerai
# Processing Record 12 of Set 6 | kavaratti
# Processing Record 13 of Set 6 | ndende
# Processing Record 14 of Set 6 | salalah
# Processing Record 15 of Set 6 | broome
# Processing Record 16 of Set 6 | high level
# Processing Record 17 of Set 6 | tim
# Processing Record 18 of Set 6 | ibotirama
# Processing Record 19 of Set 6 | wonthaggi
# Processing Record 20 of Set 6 | yenagoa
# Processing Record 21 of Set 6 | shache
# Processing Record 22 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 6 | nuuk
# Processing Record 24 of Set 6 | rawson
# Processing Record 25 of Set 6 | zhoucheng
# Processing Record 26 of Set 6 | qaqortoq
# Processing Record 27 of Set 6 | kalianget
# Processing Record 28 of Set 6 | kargopol
# Processing Record 29 of Set 6 | moose factory
# Processing Record 30 of Set 6 | beringovskiy
# Processing Record 31 of Set 6 | hualmay
# Processing Record 32 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 6 | thanh hoa
# Processing Record 34 of Set 6 | yanji
# Processing Record 35 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 6 | dingle
# Processing Record 38 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 39 of Set 6 | kainantu
# Processing Record 40 of Set 6 | oshkosh
# Processing Record 41 of Set 6 | narasannapeta
# Processing Record 42 of Set 6 | lubango
# Processing Record 43 of Set 6 | aksarka
# Processing Record 44 of Set 6 | marzuq
# Processing Record 45 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 46 of Set 6 | saldanha
# Processing Record 47 of Set 6 | sulangan
# Processing Record 48 of Set 6 | san patricio
# Processing Record 49 of Set 6 | mountain home
# Processing Record 0 of Set 7 | bubaque
# Processing Record 1 of Set 7 | taltal
# Processing Record 2 of Set 7 | laguna
# Processing Record 3 of Set 7 | husavik
# Processing Record 4 of Set 7 | hamilton
# Processing Record 5 of Set 7 | xam nua
# Processing Record 6 of Set 7 | chimbote
# Processing Record 7 of Set 7 | keuruu
# Processing Record 8 of Set 7 | xacmaz
# Processing Record 9 of Set 7 | ilulissat
# Processing Record 10 of Set 7 | buala
# Processing Record 11 of Set 7 | mount gambier
# Processing Record 12 of Set 7 | wahiawa
# Processing Record 13 of Set 7 | hoa binh
# Processing Record 14 of Set 7 | taoudenni
# Processing Record 15 of Set 7 | mahebourg
# Processing Record 16 of Set 7 | half moon bay
# Processing Record 17 of Set 7 | aswan
# Processing Record 18 of Set 7 | tombouctou
# Processing Record 19 of Set 7 | ponta delgada
# Processing Record 20 of Set 7 | vancouver
# Processing Record 21 of Set 7 | okhotsk
# Processing Record 22 of Set 7 | handwara
# City not found. Skipping...
# Processing Record 23 of Set 7 | la ronge
# Processing Record 24 of Set 7 | sompeta
# Processing Record 25 of Set 7 | srivardhan
# Processing Record 26 of Set 7 | brookhaven
# Processing Record 27 of Set 7 | kulhudhuffushi
# Processing Record 28 of Set 7 | papetoai
# Processing Record 29 of Set 7 | sao jose da coroa grande
# Processing Record 30 of Set 7 | saint-georges
# Processing Record 31 of Set 7 | inhambane
# Processing Record 32 of Set 7 | catalina
# Processing Record 33 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 34 of Set 7 | cairns
# Processing Record 35 of Set 7 | lorengau
# Processing Record 36 of Set 7 | cidreira
# Processing Record 37 of Set 7 | mount isa
# Processing Record 38 of Set 7 | disraeli
# Processing Record 39 of Set 7 | tokmak
# Processing Record 40 of Set 7 | la palma
# Processing Record 41 of Set 7 | uthal
# Processing Record 42 of Set 7 | kovdor
# Processing Record 43 of Set 7 | kirakira
# Processing Record 44 of Set 7 | valparaiso
# Processing Record 45 of Set 7 | jalapa
# Processing Record 46 of Set 7 | entre rios
# Processing Record 47 of Set 7 | tres arroyos
# Processing Record 48 of Set 7 | isabela
# Processing Record 49 of Set 7 | sochi
# Processing Record 0 of Set 8 | barcelos
# Processing Record 1 of Set 8 | harsin
# Processing Record 2 of Set 8 | soria
# Processing Record 3 of Set 8 | yulara
# Processing Record 4 of Set 8 | florianopolis
# Processing Record 5 of Set 8 | sao filipe
# Processing Record 6 of Set 8 | maningrida
# Processing Record 7 of Set 8 | falaleu
# City not found. Skipping...
# Processing Record 8 of Set 8 | santa isabel
# Processing Record 9 of Set 8 | naze
# Processing Record 10 of Set 8 | vallenar
# Processing Record 11 of Set 8 | kislyakovskaya
# Processing Record 12 of Set 8 | rocha
# Processing Record 13 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 14 of Set 8 | sembe
# Processing Record 15 of Set 8 | clarence town
# Processing Record 16 of Set 8 | tolaga bay
# Processing Record 17 of Set 8 | mahibadhoo
# Processing Record 18 of Set 8 | isangel
# Processing Record 19 of Set 8 | nome
# Processing Record 20 of Set 8 | zyryanovsk
# Processing Record 21 of Set 8 | ullapool
# Processing Record 22 of Set 8 | bentiu
# Processing Record 23 of Set 8 | ulaangom
# Processing Record 24 of Set 8 | le lorrain
# Processing Record 25 of Set 8 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 26 of Set 8 | namibe
# Processing Record 27 of Set 8 | teya
# Processing Record 28 of Set 8 | magadan
# Processing Record 29 of Set 8 | terney
# Processing Record 30 of Set 8 | lloydminster
# Processing Record 31 of Set 8 | marienburg
# Processing Record 32 of Set 8 | manta
# Processing Record 33 of Set 8 | goderich
# Processing Record 34 of Set 8 | nicoya
# Processing Record 35 of Set 8 | liberal
# Processing Record 36 of Set 8 | severo-kurilsk
# Processing Record 37 of Set 8 | mahanoro
# Processing Record 38 of Set 8 | taybad
# Processing Record 39 of Set 8 | kerema
# Processing Record 40 of Set 8 | davidson
# Processing Record 41 of Set 8 | itarema
# Processing Record 42 of Set 8 | makakilo city
# Processing Record 43 of Set 8 | pallasovka
# Processing Record 44 of Set 8 | narsaq
# Processing Record 45 of Set 8 | chihuahua
# Processing Record 46 of Set 8 | marsh harbour
# Processing Record 47 of Set 8 | nanzhang
# Processing Record 48 of Set 8 | lensk
# Processing Record 49 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 0 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 9 | lagoa
# Processing Record 2 of Set 9 | gejiu
# Processing Record 3 of Set 9 | tual
# Processing Record 4 of Set 9 | sur
# Processing Record 5 of Set 9 | west bay
# Processing Record 6 of Set 9 | wawa
# Processing Record 7 of Set 9 | swift current
# Processing Record 8 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 9 | kamina
# Processing Record 10 of Set 9 | hasaki
# Processing Record 11 of Set 9 | shingu
# Processing Record 12 of Set 9 | nishihara
# Processing Record 13 of Set 9 | belaya gora
# Processing Record 14 of Set 9 | anderson
# Processing Record 15 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 9 | pierre
# Processing Record 17 of Set 9 | broken hill
# Processing Record 18 of Set 9 | fukue
# Processing Record 19 of Set 9 | oga
# Processing Record 20 of Set 9 | kirkwall
# Processing Record 21 of Set 9 | groningen
# Processing Record 22 of Set 9 | hami
# Processing Record 23 of Set 9 | moultrie
# Processing Record 24 of Set 9 | grindavik
# Processing Record 25 of Set 9 | biu
# Processing Record 26 of Set 9 | slyudyanka
# Processing Record 27 of Set 9 | whitefish
# Processing Record 28 of Set 9 | russell
# Processing Record 29 of Set 9 | magdagachi
# Processing Record 30 of Set 9 | kaduqli
# Processing Record 31 of Set 9 | lompoc
# Processing Record 32 of Set 9 | chernyshevskiy
# Processing Record 33 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 34 of Set 9 | puerto leguizamo
# Processing Record 35 of Set 9 | champawat
# Processing Record 36 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 9 | preobrazheniye
# Processing Record 38 of Set 9 | salamiyah
# Processing Record 39 of Set 9 | larap
# Processing Record 40 of Set 9 | tura
# Processing Record 41 of Set 9 | tromso
# Processing Record 42 of Set 9 | itoman
# Processing Record 43 of Set 9 | ngunguru
# Processing Record 44 of Set 9 | araouane
# Processing Record 45 of Set 9 | acapulco
# Processing Record 46 of Set 9 | san borja
# Processing Record 47 of Set 9 | hanzhong
# Processing Record 48 of Set 9 | kathmandu
# Processing Record 49 of Set 9 | te anau
# Processing Record 0 of Set 10 | tomatlan
# Processing Record 1 of Set 10 | tungor
# Processing Record 2 of Set 10 | port macquarie
# Processing Record 3 of Set 10 | havelock
# Processing Record 4 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 5 of Set 10 | portland
# Processing Record 6 of Set 10 | la rioja
# Processing Record 7 of Set 10 | sarkand
# Processing Record 8 of Set 10 | zhigansk
# Processing Record 9 of Set 10 | makat
# Processing Record 10 of Set 10 | babai
# Processing Record 11 of Set 10 | jasper
# Processing Record 12 of Set 10 | yabrud
# Processing Record 13 of Set 10 | grenada
# Processing Record 14 of Set 10 | vao
# Processing Record 15 of Set 10 | venado tuerto
# Processing Record 16 of Set 10 | port hardy
# Processing Record 17 of Set 10 | caravelas
# Processing Record 18 of Set 10 | shimoda
# Processing Record 19 of Set 10 | bafq
# Processing Record 20 of Set 10 | wanning
# Processing Record 21 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 10 | huarmey
# Processing Record 23 of Set 10 | sosua
# Processing Record 24 of Set 10 | constantine
# Processing Record 25 of Set 10 | marystown
# Processing Record 26 of Set 10 | lewistown
# Processing Record 27 of Set 10 | lashio
# Processing Record 28 of Set 10 | porangatu
# Processing Record 29 of Set 10 | vaitape
# Processing Record 30 of Set 10 | shenkursk
# Processing Record 31 of Set 10 | hvide sande
# Processing Record 32 of Set 10 | pauini
# Processing Record 33 of Set 10 | soyo
# Processing Record 34 of Set 10 | oranjemund
# Processing Record 35 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 10 | hirara
# Processing Record 37 of Set 10 | haines junction
# Processing Record 38 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 39 of Set 10 | orlik
# Processing Record 40 of Set 10 | kununurra
# Processing Record 41 of Set 10 | lincoln
# Processing Record 42 of Set 10 | imeni babushkina
# Processing Record 43 of Set 10 | nawada
# Processing Record 44 of Set 10 | shelburne
# Processing Record 45 of Set 10 | kanniyakumari
# Processing Record 46 of Set 10 | rawah
# Processing Record 47 of Set 10 | okato
# Processing Record 48 of Set 10 | bilma
# Processing Record 49 of Set 10 | grand gaube
# Processing Record 0 of Set 11 | sao jose do belmonte
# Processing Record 1 of Set 11 | queanbeyan
# Processing Record 2 of Set 11 | antofagasta
# Processing Record 3 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 11 | sao felix do xingu
# Processing Record 5 of Set 11 | touros
# Processing Record 6 of Set 11 | takaka
# Processing Record 7 of Set 11 | nabire
# Processing Record 8 of Set 11 | quelimane
# Processing Record 9 of Set 11 | sao joao da barra
# Processing Record 10 of Set 11 | calbuco
# Processing Record 11 of Set 11 | thinadhoo
# Processing Record 12 of Set 11 | kapit
# Processing Record 13 of Set 11 | kostomuksha
# Processing Record 14 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 16 of Set 11 | samfya
# Processing Record 17 of Set 11 | mata
# Processing Record 18 of Set 11 | abu dhabi
# Processing Record 19 of Set 11 | faya
# Processing Record 20 of Set 11 | pangai
# Processing Record 21 of Set 11 | mana
# Processing Record 22 of Set 11 | warrenton
# Processing Record 23 of Set 11 | hutchinson
# Processing Record 24 of Set 11 | selma
# Processing Record 25 of Set 11 | harper
# Processing Record 26 of Set 11 | ares
# Processing Record 27 of Set 11 | sidi ali
# Processing Record 28 of Set 11 | ganzhou
# Processing Record 29 of Set 11 | san mateo del mar
# Processing Record 30 of Set 11 | taywarah
# Processing Record 31 of Set 11 | price
# Processing Record 32 of Set 11 | gatesville
# Processing Record 33 of Set 11 | margate
# Processing Record 34 of Set 11 | chernitsyno
# Processing Record 35 of Set 11 | ushtobe
# Processing Record 36 of Set 11 | hovd
# Processing Record 37 of Set 11 | evensk
# Processing Record 38 of Set 11 | peleduy
# Processing Record 39 of Set 11 | svetlogorsk
# Processing Record 40 of Set 11 | felipe carrillo puerto
# Processing Record 41 of Set 11 | eqbaliyeh
# Processing Record 42 of Set 11 | kargat
# Processing Record 43 of Set 11 | zhangye
# Processing Record 44 of Set 11 | sitka
# Processing Record 45 of Set 11 | sioux lookout
# Processing Record 46 of Set 11 | tazovskiy
# Processing Record 47 of Set 11 | puli
# Processing Record 48 of Set 11 | balkanabat
# Processing Record 49 of Set 11 | plavsk
# Processing Record 0 of Set 12 | kariba
# Processing Record 1 of Set 12 | senanga
# Processing Record 2 of Set 12 | kashiwazaki
# Processing Record 3 of Set 12 | araripe
# Processing Record 4 of Set 12 | lazaro cardenas
# Processing Record 5 of Set 12 | port hedland
# Processing Record 6 of Set 12 | maarianhamina
# Processing Record 7 of Set 12 | raudeberg
# Processing Record 8 of Set 12 | cururupu
# Processing Record 9 of Set 12 | shagonar
# Processing Record 10 of Set 12 | mbini
# Processing Record 11 of Set 12 | bara
# Processing Record 12 of Set 12 | dongli
# Processing Record 13 of Set 12 | mirabad
# Processing Record 14 of Set 12 | xichang
# Processing Record 15 of Set 12 | coihaique
# Processing Record 16 of Set 12 | katsuura
# Processing Record 17 of Set 12 | masasi
# Processing Record 18 of Set 12 | kloulklubed
# Processing Record 19 of Set 12 | svetlyy
# Processing Record 20 of Set 12 | port moresby
# Processing Record 21 of Set 12 | abu samrah
# Processing Record 22 of Set 12 | richards bay
# Processing Record 23 of Set 12 | bitung
# Processing Record 24 of Set 12 | nouna
# Processing Record 25 of Set 12 | ixtapa
# Processing Record 26 of Set 12 | rio gallegos
# Processing Record 27 of Set 12 | pacific grove
# Processing Record 28 of Set 12 | ancud
# Processing Record 29 of Set 12 | nizhniy kuranakh
# Processing Record 30 of Set 12 | yichang
# Processing Record 31 of Set 12 | xapuri
# Processing Record 32 of Set 12 | bage
# Processing Record 33 of Set 12 | muroto
# Processing Record 34 of Set 12 | dhidhdhoo
# Processing Record 35 of Set 12 | burnie
# Processing Record 36 of Set 12 | liverpool
# Processing Record 37 of Set 12 | chiredzi
# Processing Record 38 of Set 12 | palauig
# Processing Record 39 of Set 12 | carutapera
# Processing Record 40 of Set 12 | gresham
# Processing Record 41 of Set 12 | milove
# Processing Record 42 of Set 12 | chingirlau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# City          540
# Lat           540
# Lng           540
# Max Temp      540
# Humidity      540
# Cloudiness    540
# Wind Speed    540
# Country       540
# Date          540
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  souillac -20.52   57.52     73.40        83          40        5.82
# 1   rikitea -23.12 -134.97     75.16        85           7        9.48
# 2   ushuaia -54.80  -68.30     41.00        75          75        3.36
# 3   ahipara -35.17  173.17     60.75        93         100        8.90
# 4    castro -24.79  -50.01     69.93        57           0        6.76
#
#   Country        Date
# 0      MU  1590943077
# 1      PF  1590943078
# 2      AR  1590943078
# 3      NZ  1590943078
# 4      BR  1590943078

# %%
#export city_data into a csv file

city_data_pd.to_csv(output_data_file, index_label="City_ID")

# %%
city_data_pd.count()
# Out:
# City          540
# Lat           540
# Lng           540
# Max Temp      540
# Humidity      540
# Cloudiness    540
# Wind Speed    540
# Country       540
# Date          540
# dtype: int64

# %% [markdown]
# # Latitude vs. Temperature

# %%
# Build scatter plot for latitude(x) vs. temperature(y)
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude vs.Humidity plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitude vs. Cloudniess plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# # Latitue vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# # Line Regression

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Run regresson on southern hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %% [markdown]
# # Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# The r-squared is: -0.007264591038140127

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (-30,150))
# Out:
# The r-squared is: 0.034905268622195125

# %% [markdown]
# #  Cloudiness (%) vs. Latitude Linear Regression

# %%
 # Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (40,10))
# Out:
# The r-squared is: 0.0290247351011924

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (-30,30))
# Out:
# The r-squared is: 0.13532063252030488

# %% [markdown]
# # Wind Speed (mph) vs. Latitude Linear Regression

# %%
 # Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (40,25))
# Out:
# The r-squared is: 0.023206340575255755

# %%
 # Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (-30,30))
# Out:
# The r-squared is: -0.08292661982478129

# %% [markdown]
#  The low r values indicate that there is no real relationship between wind speed and latitude." The difference between the hemispheres doesn't seem to be significant enough to comment upon.
